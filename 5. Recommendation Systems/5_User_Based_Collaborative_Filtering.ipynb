# %% [markdown]
#  <h1 style="text-align: center; color: RED">İŞ BİRLİKÇİ FİLTRELEME</h1>

# %% [markdown]
#  <h2 style="text-align: center; color: RED">2-USER-BASED(KULLANICI TABANLI) COLLABORATIVE FILTERING</h2>

# %% [markdown]
# Kulllanıcı benzerlikleri üzerinden öneriler yapılır. Beğenme alışkanlıkları benzer olan kullanıcılara göre önerme işlemi yapılır.
# User-Based Collaborative Filtering (UBCF), kullanıcıların benzer ilgi alanlarına sahip diğer kullanıcılarla eşleştirilerek onlara öneriler sunulmasını sağlayan bir öneri sistemidir.
# Bu yöntemde, benzer geçmişe sahip kullanıcılar belirlenir ve bir kullanıcının izlemediği/denemediği ürünler, benzer kullanıcıların tercihleri temel alınarak önerilir.
#
# Yöntem: Kullanıcılar arasındaki benzerliklere dayalıdır.
#
# Nasıl Çalışır: Bir kullanıcının tercihlerini (puanlar, izlemeler vs.) analiz eder ve benzer zevklere sahip diğer kullanıcıların tercihlerini önerir.
#
# Öneri: Kullanıcıya benzer diğer kullanıcıların beğendiği ürünler önerilir.
#
# Örnek: Eğer Kullanıcı A, Kullanıcı B'ye benzerse, Kullanıcı A'ya B'nin izlediği ama A'nın izlemediği filmler önerilir.

# %% [markdown]
#  <h2 style="text-align: center; color: RED">UYGULAMA</h2>

# %% [markdown]
# <span style="color: blue; font-weight: bold;">1-)İş Problemi</span>
#
# Online filme izleme platformu daha önce hazırlamış olduğu tavsiye sistemini geliştirmek istmektedir.Itme-based öneri sistemini deneyen şirket daha fazla özelleştirme yapılmasını istemektedir.Yani kullanıcıların kullanıcılara benzerliği üzerinden daha fazla özelleştirmek istemektedirler.

# %% [markdown]
# <span style="color: blue; font-weight: bold;">2-)Veri Seti Hikayesi</span>
#
# Veri seti MovieLens tarafından sağlanmıştır.İçerisinde filmler ve bu filmlere verilen puanları barındırmaktadır. Veri seti yaklaşık 27000 film için yaklaşık 2000000 derecelendirme içermektedir.2 ayrı veri seti kullanıcaz.

# %% [markdown]
# <span style="color: blue; font-weight: bold;">3-)Veri Setinin Hazırlanması</span>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
movie = pd.read_csv("C:\\Users\\ASLI\\Desktop\\Data Scientist Bootcamp\\5. Recommendation Systems\\datasets\\movie_lens_dataset\\movie.csv")
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating = pd.read_csv("C:\\Users\\ASLI\\Desktop\\Data Scientist Bootcamp\\5. Recommendation Systems\\datasets\\movie_lens_dataset\\rating.csv")
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
df = movie.merge(rating, how="left", on="movieId")#ortak sütun üzerinden birleştirdik
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0     3.0     4.0  1999-12-11 13:36:47
# 1     6.0     5.0  1997-03-13 17:50:52
# 2     8.0     4.0  1996-06-05 13:37:51
# 3    10.0     4.0  1999-11-25 02:44:47
# 4    11.0     4.5  2009-01-02 01:13:41

# %%
def create_user_movie_df():
    import pandas as pd
    movie = pd.read_csv('datasets/movie_lens_dataset/movie.csv')
    rating = pd.read_csv('datasets/movie_lens_dataset/rating.csv')
    df = movie.merge(rating, how="left", on="movieId")
    comment_counts = pd.DataFrame(df["title"].value_counts())
    rare_movies = comment_counts[comment_counts["count"] <= 1000].index
    common_movies = df[~df["title"].isin(rare_movies)]
    user_movie_df = common_movies.pivot_table(index=["userId"], columns=["title"], values="rating")
    return user_movie_df

user_movie_df = create_user_movie_df()

# %%
user_movie_df
# Out:
# title     'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 1.0                      NaN                          NaN
# 2.0                      NaN                          NaN
# 3.0                      NaN                          NaN
# 4.0                      NaN                          NaN
# 5.0                      NaN                          NaN
# ...                      ...                          ...
# 138489.0                 NaN                          NaN
# 138490.0                 NaN                          NaN
# 138491.0                 NaN                          NaN
# 138492.0                 NaN                          NaN
# 138493.0                 NaN                          NaN
#
# title     *batteries not included (1987)  ...And Justice for All (1979)  \
# userId
# 1.0                                  NaN                            NaN
# 2.0                                  NaN                            NaN
# ...

# %%
#Rastgele bir kullanıcı seciyorum
random_user = int(pd.Series(user_movie_df.index).sample(1,random_state=45).values)
# Out:
# C:\Users\ASLI\AppData\Local\Temp\ipykernel_16996\2183417930.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   random_user = int(pd.Series(user_movie_df.index).sample(1,random_state=45).values)

# %%
random_user
# Out:
# 28941

# %% [markdown]
# 1. user_movie_df.index:
#
# Bu, user_movie_df'nin satır indekslerini verir.Yani kullanıcı ID’lerini temsil eder.Bu yüzden user_movie_df.index → [1, 2, 3, 4, 5, ..., 610] gibi kullanıcı ID’lerinden oluşan bir liste olur.
#
# 2. pd.Series(user_movie_df.index):
#
# Bu satır Index nesnesini bir Pandas Series’e çevirir.Neden? Çünkü .sample() metodu direkt olarak Index nesnesinde yoktur ama Series içinde vardır. Yani: .sample() kullanabilmek için bu dönüşüm yapılır.
#
# 3. .sample(1, random_state=45):
#
# Bu, seriden 1 adet rastgele kullanıcı seçmek için kullanılır.
# sample(1) → 1 tane örnek seç,
# random_state=45 → Rastgeleliği sabitler. Yani her çalıştırmada aynı kullanıcıyı seçer (reproducibility için çok önemli).
#
# 4. .values:
#
# Bu, Series'den NumPy array elde eder. Örneğin [327] gibi.
#
# 5. int(...)
#
# Son olarak bu NumPy array'in içindeki değeri (örneğin [327]) tek bir integer değere çevirir: int(array([327])) → 327
#
# Amacı: user_movie_df içinden rastgele bir kullanıcıyı (örneğin 327 numaralı kullanıcıyı) seçmek ve random_user değişkenine atamak.
#
# Bu kullanıcıyı daha sonra şu amaçla kullanırsın:
#
# O kullanıcının izlediği filmleri almak
#
# O kullanıcıya benzer diğer kullanıcıları bulmak
#
# O kullanıcıya öneri yapmak
#
# * Alternatif Kullanım
#
#   random_user = user_movie_df.sample(1, random_state=45).index[0]

# %%
random_user = user_movie_df.sample(1, random_state=45).index[0]

# %%
random_user
# Out:
# 28941.0

# %%
user_movie_df.sample(1, random_state=45).index
# Out:
# Index([28941.0], dtype='float64', name='userId')

# %%
 user_movie_df.sample(1, random_state=45).index[0]
# Out:
# 28941.0

# %% [markdown]
# <span style="color: blue; font-weight: bold;">4-)Öneri Yapılacak  Kullanıcın İzlediği Filmlerin Belirlenmesi</span>

# %%
#Veri setini şectiğimiz kullanıcıya göre indirgeyelim
random_user_df = user_movie_df[user_movie_df.index==random_user]

# %%
random_user_df
# Out:
# title    'burbs, The (1989)  (500) Days of Summer (2009)  \
# userId
# 28941.0                 NaN                          NaN
#
# title    *batteries not included (1987)  ...And Justice for All (1979)  \
# userId
# 28941.0                             NaN                            NaN
#
# title    10 Things I Hate About You (1999)  10,000 BC (2008)  \
# userId
# 28941.0                                NaN               NaN
#
# title    101 Dalmatians (1996)  \
# userId
# 28941.0                    NaN
#
# title    101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# userId
# 28941.0                                                NaN
#
# title    102 Dalmatians (2000)  12 Angry Men (1957)  12 Years a Slave (2013)  \
# userId
# 28941.0                    NaN                  NaN                      NaN
#
# title    127 Hours (2010)  13 Going on 30 (2004)  13th Warrior, The (1999)  \
# userId
# 28941.0               NaN                    NaN                       NaN
#
# ...

# %%
#Kullanıcının izlediği filmler
movies_watched = random_user_df.columns[random_user_df.notna().any()].tolist()

# %%
movies_watched
# Out:
# ['Ace Ventura: Pet Detective (1994)',
#  'Ace Ventura: When Nature Calls (1995)',
#  'Aladdin (1992)',
#  'American President, The (1995)',
#  'Apollo 13 (1995)',
#  'Babe (1995)',
#  'Bullets Over Broadway (1994)',
#  'Clueless (1995)',
#  'Disclosure (1994)',
#  'Forrest Gump (1994)',
#  'Four Weddings and a Funeral (1994)',
#  'Home Alone (1990)',
#  'Jurassic Park (1993)',
#  'Like Water for Chocolate (Como agua para chocolate) (1992)',
#  'Little Women (1994)',
#  "Mr. Holland's Opus (1995)",
#  'Mrs. Doubtfire (1993)',
#  'Much Ado About Nothing (1993)',
#  "Muriel's Wedding (1994)",
#  'Nine Months (1995)',
#  'Operation Dumbo Drop (1995)',
#  'Piano, The (1993)',
#  'Postman, The (Postino, Il) (1994)',
#  'Ready to Wear (Pret-A-Porter) (1994)',
#  'Remains of the Day, The (1993)',
#  'Sabrina (1995)',
#  "Schindler's List (1993)",
#  'Secret Garden, The (1993)',
#  'Sense and Sensibility (1995)',
#  'Shadowlands (1993)',
#  'Silence of the Lambs, The (1991)',
# ...

# %% [markdown]
#  1. random_user_df.notna():
#
# Bu kısım, DataFrame'in tüm hücrelerini kontrol eder ve NaN olmayanlar için True, olanlar için False döndürür.
#
# 2. .any():
#
# Bu ifade, sütun bazında kontrol yapar.Her sütunda en az bir True varsa o sütunu True olarak işaretler.
#
# 3. random_user_df.columns[...]
#
# Burada True olan sütunları seçiyoruz.
#
# 4. .tolist():
#
# Bu, sütun adlarını (film adlarını) listeye çevirir. Böylece  bir Python listesi elde etmiş olursun.

# %%
#komtrol amaçlı
user_movie_df.loc[user_movie_df.index==random_user,user_movie_df.columns=='Silence of the Lambs, The (1991)']
# Out:
# title    Silence of the Lambs, The (1991)
# userId
# 28941.0                               1.0

# %%
#Kullanıcın izleidği toplam film sayısı
len(movies_watched)
# Out:
# 33

# %% [markdown]
# <span style="color: blue; font-weight: bold;">5-)Aynı Filmleri İzleyen Diğer Kullanıcıların Verisine Erişmek</span>

# %%
movies_watched_df = user_movie_df[movies_watched] #aynı filmeleri izleyen kullanıcılara indirgedik

# %%
movies_watched_df
# Out:
# title     Ace Ventura: Pet Detective (1994)  \
# userId
# 1.0                                     NaN
# 2.0                                     NaN
# 3.0                                     NaN
# 4.0                                     NaN
# 5.0                                     NaN
# ...                                     ...
# 138489.0                                NaN
# 138490.0                                NaN
# 138491.0                                NaN
# 138492.0                                NaN
# 138493.0                                4.0
#
# title     Ace Ventura: When Nature Calls (1995)  Aladdin (1992)  \
# userId
# 1.0                                         NaN             NaN
# 2.0                                         NaN             NaN
# 3.0                                         NaN             NaN
# 4.0                                         3.0             NaN
# 5.0                                         NaN             5.0
# ...

# %%
#Her kullanıcı kaçar tane film izlemiş
user_movie_count = movies_watched_df.T.notnull().sum()

# %%
user_movie_count
# Out:
# userId
# 1.0          1
# 2.0          2
# 3.0          4
# 4.0          6
# 5.0         11
#             ..
# 138489.0     1
# 138490.0     7
# 138491.0     0
# 138492.0     2
# 138493.0     9
# Length: 138493, dtype: int64

# %% [markdown]
# Amaç her kullanıcının kaç film izlediğini (yani kaç filme puan verdiğini) bulmak.Buradaki “izleme” demek = kullanıcı o filme puan vermiş (yani hücre NaN değil)
#
# 1. movies_watched_df:
#
# filmler-satırda, kullanıcılar-sütunda bir DataFrame.
#
# 2. .T:
#
# Bu, DataFrame'in transpozunu alır. Yani satır ve sütun yer değiştirir.Artık Satırlar kullanıcılar ,Sütunlar filmler
#
# 3. .notnull():
#
# Bu, hücrede NaN değilse True, NaN ise False döner.
#
# 4. .sum():
#
# Bu, varsayılan olarak axis=0 yani sütun bazında toplar.
# Ama burada artık satırlar kullanıcılar olduğuna göre, her satırda kaç tane True varsa onu toplar.

# %%
#Alternatif kullanım
user_movie_count = movies_watched_df.notnull().sum(axis=1)

# %%
user_movie_count
# Out:
# userId
# 1.0          1
# 2.0          2
# 3.0          4
# 4.0          6
# 5.0         11
#             ..
# 138489.0     1
# 138490.0     7
# 138491.0     0
# 138492.0     2
# 138493.0     9
# Length: 138493, dtype: int64

# %%
user_movie_count = user_movie_count.reset_index()

# %%
user_movie_count
# Out:
#           userId   0
# 0            1.0   1
# 1            2.0   2
# 2            3.0   4
# 3            4.0   6
# 4            5.0  11
# ...          ...  ..
# 138488  138489.0   1
# 138489  138490.0   7
# 138490  138491.0   0
# 138491  138492.0   2
# 138492  138493.0   9
#
# [138493 rows x 2 columns]

# %%
user_movie_count.columns = ['userId', 'movie_count']

# %%
user_movie_count
# Out:
#           userId  movie_count
# 0            1.0            1
# 1            2.0            2
# 2            3.0            4
# 3            4.0            6
# 4            5.0           11
# ...          ...          ...
# 138488  138489.0            1
# 138489  138490.0            7
# 138490  138491.0            0
# 138491  138492.0            2
# 138492  138493.0            9
#
# [138493 rows x 2 columns]

# %%
#Sectiğimiz kullanıcı ile en az 20 tane ortak film izleyen diğer kullanıcılar
user_movie_count[user_movie_count['movie_count']>20].sort_values('movie_count',ascending=False)
# Out:
#           userId  movie_count
# 94230    94231.0           33
# 100398  100399.0           33
# 118204  118205.0           33
# 15918    15919.0           33
# 124051  124052.0           33
# ...          ...          ...
# 79214    79215.0           21
# 79174    79175.0           21
# 9105      9106.0           21
# 78515    78516.0           21
# 129        130.0           21
#
# [3202 rows x 2 columns]

# %%
#17 kişi sectiğimiz kulanıcının izlediği tüm filmeleri izlemiş
user_movie_count[user_movie_count['movie_count']==33].count()
# Out:
# userId         17
# movie_count    17
# dtype: int64

# %%
#Belirleidğimiz eşik değere göre kulanıcı ıd lerini sectik
user_same_movies = user_movie_count[user_movie_count['movie_count']>20]['userId']

# %%
user_same_movies
# Out:
# 129          130.0
# 155          156.0
# 157          158.0
# 183          184.0
# 294          295.0
#             ...
# 138207    138208.0
# 138278    138279.0
# 138381    138382.0
# 138414    138415.0
# 138482    138483.0
# Name: userId, Length: 3202, dtype: float64

# %% [markdown]
# <span style="color: blue; font-weight: bold;">6-)Öneri Yapılacak Kullanıcı ile En Benzer Davranışlı Kullanıcıların Belirlenmesi</span>
#
# Bunun için 3 adım gerçekleştiricez:
# 1) Sectiğimiz kullanıcı ve diğer kullanıcıların verilerini bir araya getiricez.
# 2) Korelasyon df'ini oluşturucaz
# 3) En benzer kullanıcıları bulucaz

# %%
final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(user_same_movies)],
                     random_user_df[movies_watched]])

# %%
final_df
# Out:
# title     Ace Ventura: Pet Detective (1994)  \
# userId
# 130.0                                   4.0
# 156.0                                   3.0
# 158.0                                   2.0
# 184.0                                   2.0
# 295.0                                   NaN
# ...                                     ...
# 138279.0                                3.0
# 138382.0                                1.0
# 138415.0                                1.0
# 138483.0                                1.0
# 28941.0                                 3.0
#
# title     Ace Ventura: When Nature Calls (1995)  Aladdin (1992)  \
# userId
# 130.0                                       3.0             NaN
# 156.0                                       NaN             NaN
# 158.0                                       1.0             4.0
# 184.0                                       3.0             3.0
# 295.0                                       NaN             3.0
# ...

# %% [markdown]
# Bu satırın amacı, tavsiye sisteminin kalbinde yer alan "benzer kullanıcılar + hedef kullanıcının filmleri" verisini birleştirmek.
#
# 1. movies_watched_df[movies_watched_df.index.isin(user_same_movies)]:
#
# Bu ifade movies_watched_df içinde yer alan sadece user_same_movies listesindeki kullanıcıları satır olarak filtreler.
#
# movies_watched_df index → kullanıcılar,  sütunlar → filmler,hücreler → puanlar
#
# user_same_movies, rastgele kullanıcının izlediği filmleri izleyen diğer kullanıcıların ID’leri.Örneğin: [12, 25, 38, 87] gibi.
#
# .isin(...)
# Index’teki kullanıcılar, user_same_movies listesindeyse True, değilse False.
#
# 2. random_user_df[movies_watched]:
#
# Rastgele seçilen kullanıcının sadece izlediği (puan verdiği) filmleri alır.random_user_df: rastgele kullanıcının user_movie_df'den alınmış bir satırı (tek kullanıcı, tüm filmler).movies_watched: bu kullanıcının puan verdiği film isimlerinin listesi.
#
# 3. pd.concat([...]):
#
# İki parçayı alt alta birleştirip tek bir DataFrame oluşturmak.

# %%
#Korelasyon hesaplama

corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 2
#       1 #Korelasyon hesaplama
# ----> 2 corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9928, in DataFrame.unstack(self, level, fill_value, sort)
#    9864 """
#    9865 Pivot a level of the (necessarily hierarchical) index labels.
#    9866
#    (...)
#    9924 dtype: float64
#    9925 """
#    9926 from pandas.core.reshape.reshape import unstack
# -> 9928 result = unstack(self, level, fill_value, sort)
#    9930 return result.__finalize__(self, method="unstack")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\reshape.py:506, in unstack(obj, level, fill_value, sort)
#     504         return _unstack_frame(obj, level, fill_value=fill_value, sort=sort)
#     505     else:
# ...

# %% [markdown]
# Bu kod, kullanıcılar arasındaki korelasyonları hesaplayıp, sıralayıp, tekrar edenleri kaldırır.
#
# 1. final_df.T:
#
# Satırlarda kullanıcılar, sütunlarda filmler vardı. Artık satırlar filmler, sütunlar kullanıcılar oldu. Korelasyon için bu hali gerekiyor!
#
# 2. .corr():
#
# Her kullanıcı çifti için Pearson korelasyon katsayısını hesaplar.Yani: “12 ile 25'in izleme/pualama davranışları ne kadar benzer?”
#
# 3. .unstack():
#
# .unstack(), bir çok seviyeli (multi-index) Series'i 2D tablo gibi göstermek yerine, 1D düz bir liste haline getirir.
#
# 12	       25	     327
#
# 12	1.00	0.98	0.95
#
# 25	0.98	1.00	0.99
#
# 327	0.95	0.99	1.00 Bu, bir 2D DataFrame: hem satırda hem sütunda kullanıcılar var.Unstack uygulanınca
#
# (row_user, col_user)	correlation
# (12, 12)	               1.00
# (25, 12)	               0.98
# (327, 12)	               0.95
#
# 4. .sort_values():
#
#
# Bu adım korelasyonları küçükten büyüğe sıralar.
#
# 5. .drop_duplicates()
#
# Bazı eşleşmeler tekrarlıdır: 12-25 ve 25-12 gibi.
#
# Bu adım sayesinde:
#
# Aynı eşleşme çiftlerinden bir tanesi tutulur.
#
# Korelasyon tablosu sadeleşir.

# %%
#matrisi oluşturduktan sonra duplica kayıtlar oldgu için unstcak hata verdi.
corr_matrix = final_df.T.corr()
print(corr_matrix.columns.duplicated().any())
print(corr_matrix.index.duplicated().any())
# Out:
# True
# True

# %%
#burda duplica kayıtlardan kurtulduk
corr_matrix = corr_matrix.loc[~corr_matrix.index.duplicated(), ~corr_matrix.columns.duplicated()]

# %%
corr_df = corr_matrix.unstack().sort_values().drop_duplicates()

# %%
corr_df
# Out:
# userId    userId
# 28866.0   67756.0    -0.936065
# 37121.0   60562.0    -0.915003
# 80593.0   34103.0    -0.898718
# 62575.0   21398.0    -0.896612
# 117826.0  48416.0    -0.883969
#                         ...
# 96952.0   34350.0     0.971667
# 68063.0   32344.0     0.977387
# 138415.0  138415.0    1.000000
# 16562.0   41005.0     1.000000
# 725.0     43765.0          NaN
# Length: 3819597, dtype: float64

# %%
#çıktıyı daha okunaklı hale getirmek için
corr_df = pd.DataFrame(corr_df, columns=['corr'])

# %%
corr_df
# Out:
#                        corr
# userId   userId
# 28866.0  67756.0  -0.936065
# 37121.0  60562.0  -0.915003
# 80593.0  34103.0  -0.898718
# 62575.0  21398.0  -0.896612
# 117826.0 48416.0  -0.883969
# ...                     ...
# 96952.0  34350.0   0.971667
# 68063.0  32344.0   0.977387
# 138415.0 138415.0  1.000000
# 16562.0  41005.0   1.000000
# 725.0    43765.0        NaN
#
# [3819597 rows x 1 columns]

# %%
corr_df.index.names = ['user_id_1', 'user_id_2']

# %%
corr_df
# Out:
#                          corr
# user_id_1 user_id_2
# 28866.0   67756.0   -0.936065
# 37121.0   60562.0   -0.915003
# 80593.0   34103.0   -0.898718
# 62575.0   21398.0   -0.896612
# 117826.0  48416.0   -0.883969
# ...                       ...
# 96952.0   34350.0    0.971667
# 68063.0   32344.0    0.977387
# 138415.0  138415.0   1.000000
# 16562.0   41005.0    1.000000
# 725.0     43765.0         NaN
#
# [3819597 rows x 1 columns]

# %%
corr_df=corr_df.reset_index()

# %%
corr_df#tüm kullanıcıların birbiri ile korelasyonu
# Out:
#          user_id_1  user_id_2      corr
# 0          28866.0    67756.0 -0.936065
# 1          37121.0    60562.0 -0.915003
# 2          80593.0    34103.0 -0.898718
# 3          62575.0    21398.0 -0.896612
# 4         117826.0    48416.0 -0.883969
# ...            ...        ...       ...
# 3819592    96952.0    34350.0  0.971667
# 3819593    68063.0    32344.0  0.977387
# 3819594   138415.0   138415.0  1.000000
# 3819595    16562.0    41005.0  1.000000
# 3819596      725.0    43765.0       NaN
#
# [3819597 rows x 3 columns]

# %%
top_users = corr_df[(corr_df['user_id_1']==random_user) & (corr_df['corr']>=0.65)][['user_id_2','corr']].reset_index(drop=True)

# %%
top_users = top_users.sort_values(by='corr', ascending=False)

# %%
top_users
# Out:
#     user_id_2      corr
# 19     7542.0  0.772183
# 18   127259.0  0.763925
# 17     7438.0  0.752716
# 16     9783.0  0.747942
# 15   117826.0  0.736011
# 14    67346.0  0.732943
# 13   131620.0  0.704478
# 12    49460.0  0.699924
# 11   121484.0  0.699161
# 10    10848.0  0.695341
# 9    128133.0  0.691538
# 8     18999.0  0.690093
# 7    125901.0  0.681795
# 6    131285.0  0.681491
# 5     26238.0  0.668515
# 4      1362.0  0.665461
# 3     61709.0  0.665115
# 2    132307.0  0.660726
# 1     94379.0  0.655596
# 0     82666.0  0.655212

# %%
top_users.rename(columns={'user_id_2':'userId'}, inplace=True)

# %%
rating = pd.read_csv("C:\\Users\\ASLI\\Desktop\\Data Scientist Bootcamp\\5. Recommendation Systems\\datasets\\movie_lens_dataset\\rating.csv")

# %%
top_users_ratings = top_users.merge(rating[['userId','movieId','rating']], how='inner')

# %%
top_users_ratings
# Out:
#        userId      corr  movieId  rating
# 0      7542.0  0.772183        6     3.0
# 1      7542.0  0.772183       10     2.0
# 2      7542.0  0.772183       17     4.0
# 3      7542.0  0.772183       19     1.0
# 4      7542.0  0.772183       21     3.0
# ...       ...       ...      ...     ...
# 9499  82666.0  0.655212      593     4.0
# 9500  82666.0  0.655212      594     4.0
# 9501  82666.0  0.655212      595     3.0
# 9502  82666.0  0.655212      597     3.0
# 9503  82666.0  0.655212      608     5.0
#
# [9504 rows x 4 columns]

# %% [markdown]
# <span style="color: blue; font-weight: bold;">7-)Skor Hesaplama</span>
#
# Kullaınıcının corr değerine göre mi bakmalıyım yoksa rantinge mi odaklanmalıyım.?

# %%
#KOrelasyon ve ratingi birbiri ile ağırlandırdık.Yani iki etkiyi beraber kullandık
top_users_ratings['weighted_rating'] = top_users_ratings['corr']*top_users_ratings['rating']

# %%
top_users_ratings
# Out:
#        userId      corr  movieId  rating  weighted_rating
# 0      7542.0  0.772183        6     3.0         2.316549
# 1      7542.0  0.772183       10     2.0         1.544366
# 2      7542.0  0.772183       17     4.0         3.088733
# 3      7542.0  0.772183       19     1.0         0.772183
# 4      7542.0  0.772183       21     3.0         2.316549
# ...       ...       ...      ...     ...              ...
# 9499  82666.0  0.655212      593     4.0         2.620847
# 9500  82666.0  0.655212      594     4.0         2.620847
# 9501  82666.0  0.655212      595     3.0         1.965635
# 9502  82666.0  0.655212      597     3.0         1.965635
# 9503  82666.0  0.655212      608     5.0         3.276059
#
# [9504 rows x 5 columns]

# %%
recommendation_df = top_users_ratings.groupby('movieId').agg({'weighted_rating':'mean'}).reset_index()

# %%
recommendation_df#kullanıcının beğenme ihtimali olan filmeler
# Out:
#       movieId  weighted_rating
# 0           1         2.330463
# 1           2         1.676988
# 2           3         1.619657
# 3           4         1.475049
# 4           5         1.624869
# ...       ...              ...
# 4321    91976         2.817912
# 4322    93320         0.704478
# 4323    95875         2.817912
# 4324    97304         2.465673
# 4325    98809         3.170151
#
# [4326 rows x 2 columns]

# %%
movies_to_be_recommend = recommendation_df[recommendation_df['weighted_rating']>3.5].sort_values('weighted_rating', ascending=False)

# %%
movies_to_be_recommend
# Out:
#       movieId  weighted_rating
# 712      1171         3.763580
# 2293     3910         3.763580
# 2111     3538         3.763580
# 1115     1922         3.763580
# 1226     2057         3.763580
# 1241     2077         3.763580
# 1512     2485         3.763580
# 1888     3118         3.763580
# 1526     2504         3.763580
# 1562     2572         3.763580
# 1587     2622         3.763580
# 1922     3179         3.721818
# 93        149         3.680055
# 1734     2883         3.680055
# 525       887         3.680055
# 1921     3178         3.680055
# 1616     2675         3.680055
# 1524     2501         3.680055
# 1351     2236         3.680055
# 1097     1893         3.680055
# 1013     1670         3.680055
# 830      1306         3.680055
# 3598     7215         3.664714
# 4062    32234         3.664714
# 3988    26394         3.664714
# 3950    25850         3.664714
# 3751     8128         3.664714
# 3676     7585         3.664714
# 3662     7490         3.664714
# ...

# %%
movies_to_be_recommend.merge(movie[['movieId','title']])#film ıd leri ile berbaer isimlerinid egörmek istedik.
# Out:
#     movieId  weighted_rating  \
# 0      1171         3.763580
# 1      3910         3.763580
# 2      3538         3.763580
# 3      1922         3.763580
# 4      2057         3.763580
# 5      2077         3.763580
# 6      2485         3.763580
# 7      3118         3.763580
# 8      2504         3.763580
# 9      2572         3.763580
# 10     2622         3.763580
# 11     3179         3.721818
# 12      149         3.680055
# 13     2883         3.680055
# 14      887         3.680055
# 15     3178         3.680055
# 16     2675         3.680055
# 17     2501         3.680055
# 18     2236         3.680055
# 19     1893         3.680055
# 20     1670         3.680055
# 21     1306         3.680055
# 22     7215         3.664714
# 23    32234         3.664714
# 24    26394         3.664714
# 25    25850         3.664714
# 26     8128         3.664714
# 27     7585         3.664714
# 28     7490         3.664714
# 29     6235         3.664714
# 30     6837         3.664714
# ...

# %% [markdown]
# <span style="color: blue; font-weight: bold;">8-)Çalışmanın Fonksiyonlaştırılması</span>

# %%
def user_based_recommender(random_user, user_movie_df, ratio=60, cor_th=0.65, score=3.5):
    import pandas as pd
    random_user_df = user_movie_df[user_movie_df.index == random_user]
    movies_watched = random_user_df.columns[random_user_df.notna().any()].tolist()
    movies_watched_df = user_movie_df[movies_watched]
    user_movie_count = movies_watched_df.T.notnull().sum()
    user_movie_count = user_movie_count.reset_index()
    user_movie_count.columns = ["userId", "movie_count"]
    perc = len(movies_watched) * ratio / 100
    users_same_movies = user_movie_count[user_movie_count["movie_count"] > perc]["userId"]

    final_df = pd.concat([movies_watched_df[movies_watched_df.index.isin(users_same_movies)],
                          random_user_df[movies_watched]])

    corr_df = final_df.T.corr().unstack().sort_values().drop_duplicates()
    corr_df = pd.DataFrame(corr_df, columns=["corr"])
    corr_df.index.names = ['user_id_1', 'user_id_2']
    corr_df = corr_df.reset_index()

    top_users = corr_df[(corr_df["user_id_1"] == random_user) & (corr_df["corr"] >= cor_th)][
        ["user_id_2", "corr"]].reset_index(drop=True)

    top_users = top_users.sort_values(by='corr', ascending=False)
    top_users.rename(columns={"user_id_2": "userId"}, inplace=True)
    rating = pd.read_csv('datasets/movie_lens_dataset/rating.csv')
    top_users_ratings = top_users.merge(rating[["userId", "movieId", "rating"]], how='inner')
    top_users_ratings['weighted_rating'] = top_users_ratings['corr'] * top_users_ratings['rating']

    recommendation_df = top_users_ratings.groupby('movieId').agg({"weighted_rating": "mean"})
    recommendation_df = recommendation_df.reset_index()

    movies_to_be_recommend = recommendation_df[recommendation_df["weighted_rating"] > score].sort_values("weighted_rating", ascending=False)
    movie = pd.read_csv('datasets/movie_lens_dataset/movie.csv')
    return movies_to_be_recommend.merge(movie[["movieId", "title"]])
